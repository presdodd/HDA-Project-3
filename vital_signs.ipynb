# %%
import os
import glob
import xml.etree.ElementTree as ET
import re
import pandas as pd
from collections import Counter

# %%
# Define the patterns for the vital signs
vital_signs_patterns = {
    'temperature': [
        r'[Tt]emperature (\d+\.?\d*)',
        r'[Tt]emperature is about (\d+\.?\d*)',
        r'[Tt]emperature is (\d+\.?\d*)',
        r'[Tt]emperature of (\d+\.?\d*)',
        r'TEMPERATURE (\d+\.?\d*)',
    ],
    'pulse': [
        r'Pulse (\d+)',
        r'Pulse is (\d+)',
        r'PULSE (\d+)',
        r'[Hh]eart rate (\d+)',
        r'HR(\d+)',
    ],
    'respiratory rate': [
        r'[Rr]espiratory rate (\d+)',
        r'[Rr]espiratory rate is (\d+)',
        r'RESPIRATORY RATE (\d+)',
        r'RESPIRATORY (\d+)',
        r'[Bb]reathing rate (\d+)',
        r'[Bb]reathing rate (\d+)',
        r'BREATHING RATE (\d+)',
        r'RP (\d+)',
        r'RR (\d+)'
    ],
    'blood pressure': [
        r'[Bb]blood pressure (\d+/\d+)',
        r'BLOOD PRESSURE (\d+/\d+)',
        r'BP (\d+/\d+)',
        r'BP: (\d+/\d+)'
    ],
    'oxygen saturation': [
        r'[Oo]xygen saturation (\d+%)',
        r'[Oo]xygen saturation (\d+%)'
        r'O2 SAT (\d+)',
    ],
    'weight': [
        r'[Ww]eight (\d+%)',
        r'WEIGHT (\d+%)',
        r'[Ww]eight is (\d+%)',
    ]
}

# %%
directory = 'Project3_data'
xml_files = glob.glob(os.path.join(directory, '*.xml'))
frequency = {sign: 0 for sign in vital_signs_patterns.keys()}
vitalSign_df = pd.DataFrame()
no_matches_found = []
files_with_vital_signs = []
for file in xml_files:
    tree = ET.parse(file)
    root = tree.getroot()
    for elem in root.iter('TEXT'):
        match = re.search(r'(\d+)-', file)
        if match:
            patient_number = match.group(1)
        else:
            print(f'Could not extract patient number from file name: {file}')
            continue

        tree = ET.parse(file)
        root = tree.getroot()
        vital_signs = []
        match_found = False
        for elem in root.iter('TEXT'):
            if elem.text:
                for sign, patterns in vital_signs_patterns.items():
                    for pattern in patterns:
                        matches = re.findall(pattern, elem.text, re.IGNORECASE)
                        if matches:
                            frequency[sign] += 1
                            if sign == 'stable/normal':
                                vital_signs.append({'patient_number': patient_number,'sign': sign, 'value': 0})
                            else:
                                vital_signs.append({'patient_number': patient_number,'sign': sign, 'value': matches[0]})
                            match_found = True
        if vital_signs:
            print(type(vitalSign_df))
            print(type(vital_signs))
            vitalSign_df = pd.concat([vitalSign_df, pd.DataFrame(vital_signs)], ignore_index=True)
        if not match_found:
            no_matches_found.append(file)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>

# %%
# vitalSign_df.head(10)

# %%
print(len(vitalSign_df))
print(len(no_matches_found))
print(no_matches_found)
## manually add some vital
new_vital_signs = [
  {'patient_number': '192','sign': 'blood pressure', 'value': '152/84'},
  {'patient_number': '192','sign': 'pulse', 'value': '68'},
  {'patient_number': '192','sign': 'weight', 'value': '263'},
  {'patient_number': '148','sign': 'blood pressure', 'value': '103/80'},
  {'patient_number': '148','sign': 'pulse', 'value': '70'},
  {'patient_number': '148','sign': 'weight', 'value': '164'},
  {'patient_number': '148','sign': 'temperature', 'value': '96.6'},
  {'patient_number': '148','sign': 'respiratory rate', 'value': '16'},
  {'patient_number': '346','sign': 'temperature', 'value': '98.6'},
  {'patient_number': '346','sign': 'pulse', 'value': '99'},
  {'patient_number': '346','sign': 'blood pressure', 'value': '174/65'},
  {'patient_number': '346','sign': 'respiratory rate', 'value': '20'},
  {'patient_number': '346','sign': 'oxygen saturation', 'value': '91%'},
  {'patient_number': '189','sign': 'blood pressure', 'value': '120/68'},
  {'patient_number': '189','sign': 'pulse', 'value': '80'},
  {'patient_number': '236','sign': 'blood pressure', 'value': '128/68'},
  {'patient_number': '236','sign': 'weight', 'value': '107'},
  {'patient_number': '338','sign': 'blood pressure', 'value': '110/61'},
  {'patient_number': '338','sign': 'pulse', 'value': '61'},
  {'patient_number': '338','sign': 'weight', 'value': '220'},
  {'patient_number': '139','sign': 'blood pressure', 'value': '140/70'},
  {'patient_number': '139','sign': 'pulse', 'value': '64'},
  {'patient_number': '139','sign': 'weight', 'value': '151'},
  {'patient_number': '385','sign': 'weight', 'value': '152'},
  {'patient_number': '385','sign': 'blood pressure', 'value': '115/55'},
  {'patient_number': '385','sign': 'pulse', 'value': '70'},
  {'patient_number': '385','sign': 'temperature', 'value': '96.3'},
  {'patient_number': '376','sign': 'weight', 'value': '183'},
  {'patient_number': '376','sign': 'blood pressure', 'value': '130/70'},
  {'patient_number': '397','sign': 'temperature', 'value': '98.3'},
  {'patient_number': '397','sign': 'blood pressure', 'value': '114/73'},
  {'patient_number': '397','sign': 'pulse', 'value': '100'},
  {'patient_number': '397','sign': 'respiratory rate', 'value': '16'},
  {'patient_number': '397','sign': 'oxygen saturation', 'value': '96%'},
  {'patient_number': '278','sign': 'blood pressure', 'value': '130/72'},
  {'patient_number': '278','sign': 'pulse', 'value': '68'},
  {'patient_number': '278','sign': 'weight', 'value': '198'},
  {'patient_number': '242','sign': 'blood pressure', 'value': '142/84'},
  {'patient_number': '242','sign': 'weight', 'value': '178'},
  {'patient_number': '242','sign': 'weight', 'value': '178'},
  {'patient_number': '110','sign': 'pulse', 'value': '66'},
  {'patient_number': '110','sign': 'temperature', 'value': '98.7'},
  {'patient_number': '110','sign': 'oxygen saturation', 'value': '97%'},
  {'patient_number': '110','sign': 'blood pressure', 'value': '132/60'},
  {'patient_number': '244','sign': 'blood pressure', 'value': '120/64'},
  {'patient_number': '244','sign': 'pulse', 'value': '68'},
  {'patient_number': '244','sign': 'respiratory rate', 'value': '14'},
  {'patient_number': '244','sign': 'weight', 'value': '202'},
  {'patient_number': '354','sign': 'blood pressure', 'value': '154/71'},
  {'patient_number': '354','sign': 'pulse', 'value': '66'},
  {'patient_number': '346','sign': 'blood pressure', 'value': '124/60'},
  {'patient_number': '346','sign': 'pulse', 'value': '72'},
  {'patient_number': '346','sign': 'weight', 'value': '238'},
  {'patient_number': '220','sign': 'blood pressure', 'value': '140/82'},
  {'patient_number': '220','sign': 'temperature', 'value': '98.2'},
  {'patient_number': '378','sign': 'weight', 'value': '213'},
  {'patient_number': '215','sign': 'blood pressure', 'value': '130/80'},
  {'patient_number': '215','sign': 'weight', 'value': '216'},
  {'patient_number': '346','sign': 'temperature', 'value': '98.6'},
  {'patient_number': '346','sign': 'pulse', 'value': '99'},
  {'patient_number': '346','sign': 'blood pressure', 'value': '174/65'},
  {'patient_number': '346','sign': 'respiratory rate', 'value': '20'},
  {'patient_number': '346','sign': 'oxygen saturation', 'value': '91%'},
]

new_vital_signs_df = pd.DataFrame(new_vital_signs)
vitalSign_df = pd.concat([vitalSign_df, new_vital_signs_df], ignore_index=True)
# Out:
# 1375
# 595
# ['Project3_data/119-01.xml', 'Project3_data/388-05.xml', 'Project3_data/288-05.xml', 'Project3_data/107-01.xml', 'Project3_data/185-02.xml', 'Project3_data/367-03.xml', 'Project3_data/174-04.xml', 'Project3_data/105-04.xml', 'Project3_data/316-03.xml', 'Project3_data/176-01.xml', 'Project3_data/197-02.xml', 'Project3_data/220-02.xml', 'Project3_data/168-01.xml', 'Project3_data/208-03.xml', 'Project3_data/308-02.xml', 'Project3_data/208-02.xml', 'Project3_data/375-02.xml', 'Project3_data/275-02.xml', 'Project3_data/140-01.xml', 'Project3_data/220-03.xml', 'Project3_data/197-03.xml', 'Project3_data/294-01.xml', 'Project3_data/316-02.xml', 'Project3_data/150-04.xml', 'Project3_data/174-05.xml', 'Project3_data/298-01.xml', 'Project3_data/296-04.xml', 'Project3_data/121-04.xml', 'Project3_data/332-03.xml', 'Project3_data/232-03.xml', 'Project3_data/288-04.xml', 'Project3_data/204-02.xml', 'Project3_data/386-01.xml', 'Project3_data/131-01.xml', 'Project3_data/286-01.xml', 'Project3_data/222-04.xml', 'Project3_data/119-02.xml', 'Project3_data/251-01.xml', 'Project3_data/185-01.xml', 'Project3_data/152-03.xml', 'Project3_data/398-03.xml', 'Project3_data/241-04.xml', 'Project3_data/341-04.xml', 'Project3_data/187-04.xml', 'Project3_data/330-04.xml', 'Project3_data/189-01.xml', 'Project3_data/294-03.xml', 'Project3_data/176-02.xml', 'Project3_data/115-02.xml', 'Project3_data/197-01.xml', 'Project3_data/168-02.xml', 'Project3_data/208-01.xml', 'Project3_data/306-04.xml', 'Project3_data/206-04.xml', 'Project3_data/275-01.xml', 'Project3_data/375-01.xml', 'Project3_data/115-03.xml', 'Project3_data/318-04.xml', 'Project3_data/176-03.xml', 'Project3_data/216-01.xml', 'Project3_data/123-02.xml', 'Project3_data/265-04.xml', 'Project3_data/187-05.xml', 'Project3_data/298-02.xml', 'Project3_data/314-04.xml', 'Project3_data/367-01.xml', 'Project3_data/107-03.xml', 'Project3_data/204-01.xml', 'Project3_data/119-03.xml', 'Project3_data/279-01.xml', 'Project3_data/117-02.xml', 'Project3_data/195-01.xml', 'Project3_data/288-03.xml', 'Project3_data/251-04.xml', 'Project3_data/109-02.xml', 'Project3_data/232-04.xml', 'Project3_data/241-01.xml', 'Project3_data/341-01.xml', 'Project3_data/296-03.xml', 'Project3_data/121-03.xml', 'Project3_data/150-03.xml', 'Project3_data/187-01.xml', 'Project3_data/230-01.xml', 'Project3_data/105-02.xml', 'Project3_data/243-04.xml', 'Project3_data/199-01.xml', 'Project3_data/320-04.xml', 'Project3_data/197-04.xml', 'Project3_data/166-02.xml', 'Project3_data/384-03.xml', 'Project3_data/284-03.xml', 'Project3_data/306-01.xml', 'Project3_data/206-01.xml', 'Project3_data/197-05.xml', 'Project3_data/375-04.xml', 'Project3_data/216-04.xml', 'Project3_data/178-03.xml', 'Project3_data/316-04.xml', 'Project3_data/218-01.xml', 'Project3_data/365-01.xml', 'Project3_data/265-01.xml', 'Project3_data/150-02.xml', 'Project3_data/121-02.xml', 'Project3_data/296-02.xml', 'Project3_data/314-01.xml', 'Project3_data/267-04.xml', 'Project3_data/388-02.xml', 'Project3_data/279-04.xml', 'Project3_data/277-01.xml', 'Project3_data/377-01.xml', 'Project3_data/119-04.xml', 'Project3_data/195-02.xml', 'Project3_data/222-02.xml', 'Project3_data/117-01.xml', 'Project3_data/109-01.xml', 'Project3_data/107-04.xml', 'Project3_data/269-03.xml', 'Project3_data/369-03.xml', 'Project3_data/214-03.xml', 'Project3_data/314-03.xml', 'Project3_data/187-02.xml', 'Project3_data/330-02.xml', 'Project3_data/176-04.xml', 'Project3_data/140-05.xml', 'Project3_data/253-02.xml', 'Project3_data/166-01.xml', 'Project3_data/253-03.xml', 'Project3_data/140-04.xml', 'Project3_data/123-04.xml', 'Project3_data/187-03.xml', 'Project3_data/330-03.xml', 'Project3_data/230-03.xml', 'Project3_data/365-02.xml', 'Project3_data/296-01.xml', 'Project3_data/121-01.xml', 'Project3_data/214-02.xml', 'Project3_data/398-04.xml', 'Project3_data/241-03.xml', 'Project3_data/298-04.xml', 'Project3_data/369-02.xml', 'Project3_data/386-04.xml', 'Project3_data/222-03.xml', 'Project3_data/195-03.x ...

# %%
## drop duplicate rows
# vitalSign_df = vitalSign_df.drop_duplicates()
# len(vitalSign_df)

# %%
vitalSign_df.to_csv('largeVitalSigns.csv', index=False)

# %%
sign_frequency = vitalSign_df['sign'].value_counts()
print(sign_frequency)
# Out:
# sign
# blood pressure       578
# pulse                398
# respiratory rate     251
# temperature          178
# oxygen saturation     19
# weight                14
# Name: count, dtype: int64

# %%
## bar chart of the frequency of each vital sign
import matplotlib.pyplot as plt

ax = sign_frequency.plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# plt.show()

# %%
## drop frequency and plot
